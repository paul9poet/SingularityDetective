# %% [markdown]
# # Notebook Title
#
# Replace this text with the actual title and purpose of your notebook.

# %% [markdown]
# ## Overview
# Describe what this notebook is about and what the reader should expect.

# %%
# Example Python code cell — replace with real code
x = 42
x
# Out:
# 42

# %% [markdown]
# ## Next Steps
# - Add your first code block here
# - Add narrative explaining the context
# - Add plots, diagrams, etc.
